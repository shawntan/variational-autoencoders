# %%
# %matplotlib inline
import numpy as np
import cPickle as pickle
import matplotlib.pyplot as plt
from theano_toolkit.parameters import Parameters

import model

# %%
P = Parameters()
_,sample = model.build(P,"vrnn")
f = theano.function(inputs=[],outputs=sample())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-c4bc903f447f> in <module>()
#       1 P = Parameters()
#       2 _,sample = model.build(P,"vrnn")
# ----> 3 f = theano.function(inputs=[],outputs=sample())
#
# NameError: name 'theano' is not defined

# %%
P.load('model.pkl')

# %%
data = f()
data = data.reshape(data.shape[0] * data.shape[2])

# %%
plt.plot(data)
